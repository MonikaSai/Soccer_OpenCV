# %%
import cv2
import os
import numpy as np

vidcap = cv2.VideoCapture('player detection.mp4')
success,image = vidcap.read()
success = True

while success:

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, (36, 0, 0), (70, 255,255))
    res = cv2.bitwise_and(image, image, mask=mask)
    cv2.imshow('frame',res)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    success,image = vidcap.read()
    
vidcap.release()
cv2.destroyAllWindows()

# %%
import cv2 
import os 
import numpy.core.multiarray
import numpy as np
import time

vidcap = cv2.VideoCapture('new soccer video.mp4')
out = cv2.VideoWriter('output.mp4',-1, 20.0, (1720,750))
success,image = vidcap.read()
success = True

upper_green = np.array([70,255, 255])
lower_green = np.array([40,40, 40])

lower_blue = np.array([110,50,50])
upper_blue = np.array([130,255,255])

lower_white = np.array([0,31,255])
upper_white = np.array([176,255,255])

lower_yellow = np.array([20, 100, 100])
upper_yellow = np.array([30, 255, 255])

lower_black = np.array([20, 100, 100])
upper_black = np.array([180, 255, 30])


def detect_player(player_img, low_color, upper_color):
    player_hsv = cv2.cvtColor(player_img,cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(player_hsv, low_color, upper_color)
    res = cv2.bitwise_and(player_img, player_img, mask=mask)
    res = cv2.cvtColor(res,cv2.COLOR_BGR2GRAY)
    nzCount = cv2.countNonZero(res)
    return nzCount

while success:
    time.sleep(0.01)

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower_green, upper_green)
    res = cv2.bitwise_and(image, image, mask=mask)
    res_gray = cv2.cvtColor(res,cv2.COLOR_BGR2GRAY)
    _, contours, _ = cv2.findContours(res_gray ,
                                   cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for c in contours:
        x,y,w,h = cv2.boundingRect(c)
        if(h>=(1.5)*w):
            if(w>15 and h>= 15):
                player_img = image[y:y+h,x:x+w]
                Team_A = detect_player(player_img, lower_blue, upper_blue)
                Team_B = detect_player(player_img, lower_white, upper_white)
                if(Team_A >= 20):
                    cv2.putText(image, 'Team_A', (x-2, y-2), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,0,0), 2, cv2.LINE_AA)
                    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),3)
                if(Team_B>=20):
                    cv2.putText(image, 'Team_B', (x-2, y-2), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,0,255), 2, cv2.LINE_AA)
                    cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),3)

    cv2.imshow('frame',image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    success,image = vidcap.read()
    
vidcap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
camera = video_frame = cv2.VideoCapture("new soccer video.mp4")
out = cv2.VideoWriter('outputttt.mp4',-1, 20.0, (1720,750)) #cv2.VideoWriter('video.avi',cv2.VideoWriter_fourcc(*'MPEG'),30,(width,height))

firstFrame = None
p=0
y_1=330
h_1=1070
x_1=200
w_1=1800
# loop over the frames of the video
upper_green = np.array([70,255, 255])
lower_green = np.array([40,40, 40])

lower_blue = np.array([110,50,50])
upper_blue = np.array([130,255,255])

lower_white = np.array([0,31,255])
upper_white = np.array([176,255,255])

lower_yellow = np.array([20, 100, 100])
upper_yellow = np.array([30, 255, 255])

lower_black = np.array([20, 100, 100])
upper_black = np.array([180, 255, 30])


def detect_player(player_img, low_color, upper_color):
    player_hsv = cv2.cvtColor(player_img,cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(player_hsv, low_color, upper_color)
    res = cv2.bitwise_and(player_img, player_img, mask=mask)
    res = cv2.cvtColor(res,cv2.COLOR_BGR2GRAY)
    nzCount = cv2.countNonZero(res)
    return nzCount

while success:
    time.sleep(0.01)

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower_green, upper_green)
    res = cv2.bitwise_and(image, image, mask=mask)
    res_gray = cv2.cvtColor(res,cv2.COLOR_BGR2GRAY)
    _, contours, _ = cv2.findContours(res_gray ,
                                   cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for c in contours:
        x,y,w,h = cv2.boundingRect(c)
        if(h>=(1.5)*w):
            if(w>15 and h>= 15):
                player_img = image[y:y+h,x:x+w]
                Team_A = detect_player(player_img, lower_blue, upper_blue)
                Team_B = detect_player(player_img, lower_white, upper_white)
                if(Team_A >= 20):
                    cv2.putText(image, 'Team_A', (x-2, y-2), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,0,0), 2, cv2.LINE_AA)
                    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),3)
                if(Team_B>=20):
                    cv2.putText(image, 'Team_B', (x-2, y-2), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,0,255), 2, cv2.LINE_AA)
                    cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),3)

    
#     cv2.imshow('fram',thresh)
    cv2.imshow('frame',frame)
    key = cv2.waitKey(1) & 0xFF
    # if the `q` key is pressed, break from the lop
    if key == ord("q"):
        break
# cleanup the camera and close any open windows
camera.release()
out.release()
cv2.destroyAllWindows()
